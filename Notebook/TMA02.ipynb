# %% [markdown]
# ## 1. Start to get a feel for the data

# %% [markdown]
# When dealing with new datasets, it is always useful to look over any relevant documentation to get a feel for the data you will be handling.
#
# Investigate the *Connected Nations 2022: Interactive report* (Ofcom, 2023a) which is available at:
#
#    https://www.ofcom.org.uk/research-and-data/multi-sector-research/infrastructure-research/connected-nations-2022/interactive-report
#
# One of the investigations you should do is to compare the fixed broadband coverage in your local authority with that of the UK as a whole. Take a single screenshot of what you have found and explain in no more than 100 words what the result says about broadband coverage in your local authority.
#
# If you are not based in the UK then if possible choose a local authority with which you have some connection.

# %% [markdown]
# **You must include your screenshot in the `images/` directory.**

# %% [markdown]
# *(3 marks)*
#
# Ofcom (2023a) *Connected Nations 2022: Interactive report*. Available at: https://www.ofcom.org.uk/research-and-data/multi-sector-research/infrastructure-research/connected-nations-2022/interactive-report (Accessed: 26 September 2023).

# %% [markdown]
# **Write your answer and include your image in this markdown cell**
#
# <img src="images/screen2.png">

# %% [markdown]
# This indicates the coverage of premises by fixed broadband networks in Ealing compared to the UK. The bar graphs' shapes in Ealing resemble those of the UK, with '>= 10 Mbit/s' being the highest and <10 Mbit/s DL being the lowest. However, Full Fibre coverage in Ealing accounts for 31%, whereas the UK has 41%. Therefore, the Full Fibre  networks in Ealing have improved, though not to the same extent as across the entire UK.

# %% [markdown]
# ## 2. Store the data in a MongoDB database

# %% [markdown]
# The datafiles for fixed broadband coverage in the UK are found in the folder:
# ```
#     2023J_TMA02_data/Ofcom_fixed
# ```
# There are five csv files - one for each year - the year is indicated in the filename. Each csv file has an associated pdf which includes metadata. The datafiles and metadata pdfs were downloaded from Ofcom (2023b). The data is made available by Ofcom under the [Open Government Licence v3.0](https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/).
#
# Your first task is to import the data, clean it, and store it in MongoDB. You will need to use '2019–2023 structural changes to local government in England' (2023) because you will need to be able to compare broadband coverage between different years.
#
# When doing this you should consider that:
#
# - Not all the csv have the same column names.
# - Not all the csv have the same number of columns.
# - There is ambiguous data.
# - The year is not included in the file, only in the filename.
#
# As well as the data imported from the csv files, each MongoDB document should have a field with a value referencing the year that the data was collected.
#
# You might find it useful to use python's [glob](https://docs.python.org/3.8/library/glob.html) or [os](https://docs.python.org/3.8/library/os.html) modules which allow you to create a list of filenames in a directory.
#
# Use comments and Markdown cells to discuss and justify any decisions you make when importing the data.
#
# *(10 marks)*
#
# '2019–2023 structural changes to local government in England' (2023) Wikipedia. Available at: https://en.wikipedia.org/wiki/2019%E2%80%932023_structural_changes_to_local_government_in_England (Accessed: 26 September 2023).
#
# Ofcom (2023b) *Connected Nations and infrastructure reports*. Available at: https://www.ofcom.org.uk/research-and-data/multi-sector-research/infrastructure-research (Accessed: 24 September 2023).

# %%
# Write your answer in this code cell.
# Use additional cells if necessary, including markdown
# cells to explain your decisions and code.

import pandas as pd
import matplotlib.pyplot as plt
import glob
import re
import chardet

import pymongo
import folium

# %%
# !ls 2023J_TMA02_data/Ofcom_fixed
# Out:
# 201909_fixed_laua_coverage_r01.csv
# 202009_fixed_laua_coverage_r01.csv
# 202109_fixed_laua_coverage_r01.csv
# 202209-about-fixed-local-and-unitary-authority.pdf
# 202209_fixed_laua_coverage_r02.csv
# 202305_fixed_laua_coverage_r02.csv
# cn-2020-about-fixed-coverage-local-and-unitary-authority.pdf
# cn-2021-about-fixed-laua-coverage.pdf
# connected-nations-2019-about-fixed-local-unitary-authority-area.pdf
# fixed-coverage-local-unitary-authority-202305-v2.pdf

# %% [markdown]
# ### 2019

# %%
# Check encoding
chardet.detect(open('2023J_TMA02_data/Ofcom_fixed/201909_fixed_laua_coverage_r01.csv','rb').read())
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %% [markdown]
# data file:
# - encoding:  ascii

# %%
# Read the CSV file into a DataFrame
df2019 = pd.read_csv('2023J_TMA02_data/Ofcom_fixed/201909_fixed_laua_coverage_r01.csv', encoding='ascii')

# %%
df2019.head()
# Out:
#         laua      laua_name  All Premises  All Matched Premises  \
# 0  S12000033  ABERDEEN CITY        125441                125311
# 1  S12000034  ABERDEENSHIRE        125085                124305
# 2  E07000223           ADUR         29770                 29760
# 3  E07000026      ALLERDALE         51385                 51284
# 4  E07000032   AMBER VALLEY         60674                 60596
#
#    SFBB availability (% premises)  UFBB availability (% premises)  \
# 0                            73.3                            20.1
# 1                            78.5                             2.8
# 2                            16.3                            82.4
# 3                            89.8                             1.7
# 4                            67.4                            25.3
#
#    Full Fibre availability (% premises)  \
# 0                                  13.1
# 1                                   2.7
# 2                                   0.6
# 3                                   1.7
# 4                                  22.1
#
#    % of premises unable to receive 2Mbit/s  \
# 0                                      0.0
# 1                                      2.5
# 2                                      0.0
# 3                                      1.2
# 4                                      0.1
#
#    % of premises unable to receive 5Mbit/s  \
# 0                                      0.2
# 1                                      5.9
# 2                                      0.1
# 3                                      2.6
# 4                                      0.9
#
#    % of premises unable to receive 10Mbit/s  ...  \
# 0                                       0.7  ...
# 1                                       9.9  ...
# 2                                       0.1  ...
# 3                                       3.6  ...
# 4                                       2.1  ...
#
#    Number of premises with 0<2Mbit/s download speed  \
# 0                                                49
# 1                                              3163
# 2                                                 0
# 3                                               619
# 4                                                89
#
#    Number of premises with 2<5Mbit/s download speed  \
# 0                                               170
# 1                                              4176
# 2                                                16
# 3                                               704
# 4                                               460
#
#    Number of premises with 5<10Mbit/s download speed  \
# 0                                                665
# 1                                               4993
# 2                                                 28
# 3                                                550
# 4                                                705
#
#    Number of premises with 10<30Mbit/s download speed  \
# 0                                               7275
# 1                                              10321
# 2                                                333
# 3                                               2408
# 4                                               3110
#
#    % of premises with 30<300Mbit/s download speed  \
# 0                                            73.3
# 1                                            78.5
# 2                                            16.3
# 3                                            89.8
# 4                                            67.4
#
#    % of premises with >=300Mbit/s download speed  \
# 0                                           20.1
# 1                                            2.8
# 2                                           82.4
# 3                                            1.7
# 4                                           25.3
#
#    % of premises with 0<2Mbit/s download speed  \
# 0                                          0.0
# 1                                          2.5
# 2                                          0.0
# 3                                          1.2
# 4                                          0.1
#
#    % of premises with 2<5Mbit/s download speed  \
# 0                                          0.1
# 1                                          3.3
# 2                                          0.1
# 3                                          1.4
# 4                                          0.8
#
#    % of premises with 5<10Mbit/s download speed  \
# 0                                           0.5
# 1                                           4.0
# 2                                           0.1
# 3                                           1.1
# 4                                           1.2
#
#    % of premises with 10<30Mbit/s download speed
# 0                                            5.8
# 1                                            8.3
# 2                                            1.1
# 3                                            4.7
# 4                                            5.1
#
# [5 rows x 38 columns]

# %%
df2019.tail()
# Out:
#           laua    laua_name  All Premises  All Matched Premises  \
# 377  E07000238     WYCHAVON         62475                 62114
# 378  E07000007      WYCOMBE         76433                 76345
# 379  E07000128         WYRE         56343                 56280
# 380  E07000239  WYRE FOREST         48100                 48061
# 381  E06000014         YORK         98735                 98548
#
#      SFBB availability (% premises)  UFBB availability (% premises)  \
# 377                            82.9                             8.6
# 378                            68.5                            26.5
# 379                            88.4                             5.9
# 380                            49.3                            46.7
# 381                            23.0                            70.8
#
#      Full Fibre availability (% premises)  \
# 377                                   5.1
# 378                                   2.2
# 379                                   5.5
# 380                                   0.9
# 381                                  43.6
#
#      % of premises unable to receive 2Mbit/s  \
# 377                                      0.2
# 378                                      0.1
# 379                                      0.1
# 380                                      0.3
# 381                                      0.0
#
#      % of premises unable to receive 5Mbit/s  \
# 377                                      0.9
# 378                                      0.6
# 379                                      0.3
# 380                                      0.6
# 381                                      0.3
#
#      % of premises unable to receive 10Mbit/s  ...  \
# 377                                       2.0  ...
# 378                                       1.0  ...
# 379                                       0.7  ...
# 380                                       1.4  ...
# 381                                       0.6  ...
#
#      Number of premises with 0<2Mbit/s download speed  \
# 377                                               129
# 378                                                90
# 379                                                69
# 380                                               140
# 381                                                36
#
#      Number of premises with 2<5Mbit/s download speed  \
# 377                                               424
# 378                                               399
# 379                                               114
# 380                                               151
# 381                                               225
#
#      Number of premises with 5<10Mbit/s download speed  \
# 377                                                670
# 378                                                242
# 379                                                199
# 380                                                371
# 381                                                368
#
#      Number of premises with 10<30Mbit/s download speed  \
# 377                                               3761
# 378                                               3050
# 379                                               2725
# 380                                               1196
# 381                                               5293
#
#      % of premises with 30<300Mbit/s download speed  \
# 377                                            82.9
# 378                                            68.5
# 379                                            88.4
# 380                                            49.3
# 381                                            23.0
#
#      % of premises with >=300Mbit/s download speed  \
# 377                                            8.6
# 378                                           26.5
# 379                                            5.9
# 380                                           46.7
# 381                                           70.8
#
#      % of premises with 0<2Mbit/s download speed  \
# 377                                          0.2
# 378                                          0.1
# 379                                          0.1
# 380                                          0.3
# 381                                          0.0
#
#      % of premises with 2<5Mbit/s download speed  \
# 377                                          0.7
# 378                                          0.5
# 379                                          0.2
# 380                                          0.3
# 381                                          0.2
#
#      % of premises with 5<10Mbit/s download speed  \
# 377                                           1.1
# 378                                           0.3
# 379                                           0.4
# 380                                           0.8
# 381                                           0.4
#
#      % of premises with 10<30Mbit/s download speed
# 377                                            6.0
# 378                                            4.0
# 379                                            4.8
# 380                                            2.5
# 381                                            5.4
#
# [5 rows x 38 columns]

# %%
# Data volume
df2019.shape
# Out:
# (382, 38)

# %%
# Data type
df2019.dtypes
# Out:
# laua                                                             object
# laua_name                                                        object
# All Premises                                                      int64
# All Matched Premises                                              int64
# SFBB availability (% premises)                                  float64
# UFBB availability (% premises)                                  float64
# Full Fibre availability (% premises)                            float64
# % of premises unable to receive 2Mbit/s                         float64
# % of premises unable to receive 5Mbit/s                         float64
# % of premises unable to receive 10Mbit/s                        float64
# % of premises unable to receive 30Mbit/s                        float64
# % of premises below the USO                                     float64
# % of premises with NGA                                          float64
# % of premises able to receive decent broadband from FWA         float64
# % of premises able to receive SFBB from FWA                     float64
# Number of premises with SFBB availability                         int64
# Number of premises with UFBB availability                         int64
# Number of premises with Full Fibre availability                   int64
# Number of premises unable to receive 2Mbit/s                      int64
# Number of premises unable to receive 5Mbit/s                      int64
# Number of premises unable to receive 10Mbit/s                     int64
# Number of premises unable to receive 30Mbit/s                     int64
# Number of premises below the USO                                  int64
# Number of premises with NGA                                       int64
# Number of premises able to receive decent broadband from FWA      int64
# Number of premises able to receive SFBB from FWA                  int64
# Number of premises with 30<300Mbit/s download speed               int64
# Number of premises with >=300Mbit/s download speed                int64
# Number of premises with 0<2Mbit/s download speed                  int64
# Number of premises with 2<5Mbit/s download speed                  int64
# Number of premises with 5<10Mbit/s download speed                 int64
# Number of premises with 10<30Mbit/s download speed                int64
# % of premises with 30<300Mbit/s download speed                  float64
# % of premises with >=300Mbit/s download speed                   float64
# % of premises with 0<2Mbit/s download speed                     float64
# % of premises with 2<5Mbit/s download speed                     float64
# % of premises with 5<10Mbit/s download speed                    float64
# % of premises with 10<30Mbit/s download speed                   float64
# dtype: object

# %%
# Count null values
df2019.isnull().sum()
# Out:
# laua                                                            0
# laua_name                                                       0
# All Premises                                                    0
# All Matched Premises                                            0
# SFBB availability (% premises)                                  0
# UFBB availability (% premises)                                  0
# Full Fibre availability (% premises)                            0
# % of premises unable to receive 2Mbit/s                         0
# % of premises unable to receive 5Mbit/s                         0
# % of premises unable to receive 10Mbit/s                        0
# % of premises unable to receive 30Mbit/s                        0
# % of premises below the USO                                     0
# % of premises with NGA                                          0
# % of premises able to receive decent broadband from FWA         0
# % of premises able to receive SFBB from FWA                     0
# Number of premises with SFBB availability                       0
# Number of premises with UFBB availability                       0
# Number of premises with Full Fibre availability                 0
# Number of premises unable to receive 2Mbit/s                    0
# Number of premises unable to receive 5Mbit/s                    0
# Number of premises unable to receive 10Mbit/s                   0
# Number of premises unable to receive 30Mbit/s                   0
# Number of premises below the USO                                0
# Number of premises with NGA                                     0
# Number of premises able to receive decent broadband from FWA    0
# Number of premises able to receive SFBB from FWA                0
# Number of premises with 30<300Mbit/s download speed             0
# Number of premises with >=300Mbit/s download speed              0
# Number of premises with 0<2Mbit/s download speed                0
# Number of premises with 2<5Mbit/s download speed                0
# Number of premises with 5<10Mbit/s download speed               0
# Number of premises with 10<30Mbit/s download speed              0
# % of premises with 30<300Mbit/s download speed                  0
# % of premises with >=300Mbit/s download speed                   0
# % of premises with 0<2Mbit/s download speed                     0
# % of premises with 2<5Mbit/s download speed                     0
# % of premises with 5<10Mbit/s download speed                    0
# % of premises with 10<30Mbit/s download speed                   0
# dtype: int64

# %%
# Select only numerical columns
numerical_columns = df2019.select_dtypes(include=['number'])

# Use describe on numerical columns
numerical_description = numerical_columns.describe()

# Display the numerical description
display(numerical_description)
# Out:
#         All Premises  All Matched Premises  SFBB availability (% premises)  \
# count     382.000000            382.000000                      382.000000
# mean    80678.520942          80532.005236                       46.587435
# std     52521.559617          52472.885870                       25.255563
# min      1681.000000           1678.000000                        1.100000
# 25%     48100.250000          48070.250000                       24.225000
# 50%     64867.500000          64782.500000                       42.450000
# 75%     98485.750000          98413.250000                       69.850000
# max    469208.000000         468772.000000                       97.800000
#
#        UFBB availability (% premises)  Full Fibre availability (% premises)  \
# count                      382.000000                            382.000000
# mean                        46.857068                              8.586649
# std                         28.551654                             10.401911
# min                          0.000000                              0.000000
# 25%                         18.450000                              2.400000
# 50%                         51.800000                              4.950000
# 75%                         72.175000                             11.100000
# max                         97.000000                             97.000000
#
#        % of premises unable to receive 2Mbit/s  \
# count                               382.000000
# mean                                  0.408639
# std                                   0.794339
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.100000
# 75%                                   0.400000
# max                                   7.900000
#
#        % of premises unable to receive 5Mbit/s  \
# count                               382.000000
# mean                                  1.091361
# std                                   1.663883
# min                                   0.000000
# 25%                                   0.100000
# 50%                                   0.400000
# 75%                                   1.300000
# max                                  13.500000
#
#        % of premises unable to receive 10Mbit/s  \
# count                                382.000000
# mean                                   2.078534
# std                                    2.823999
# min                                    0.000000
# 25%                                    0.400000
# 50%                                    1.000000
# 75%                                    2.500000
# max                                   21.400000
#
#        % of premises unable to receive 30Mbit/s  % of premises below the USO  \
# count                                382.000000                   382.000000
# mean                                   6.335340                     0.643717
# std                                    5.478259                     1.072613
# min                                    0.200000                     0.000000
# 25%                                    2.700000                     0.100000
# 50%                                    4.800000                     0.200000
# 75%                                    7.800000                     0.700000
# max                                   46.000000                     7.100000
#
#        ...  Number of premises with 0<2Mbit/s download speed  \
# count  ...                                        382.000000
# mean   ...                                        246.921466
# std    ...                                        449.014551
# min    ...                                          0.000000
# 25%    ...                                         15.000000
# 50%    ...                                         77.500000
# 75%    ...                                        279.750000
# max    ...                                       3947.000000
#
#        Number of premises with 2<5Mbit/s download speed  \
# count                                        382.000000
# mean                                         430.123037
# std                                          551.411163
# min                                            0.000000
# 25%                                           72.250000
# 50%                                          225.000000
# 75%                                          536.000000
# max                                         4176.000000
#
#        Number of premises with 5<10Mbit/s download speed  \
# count                                         382.000000
# mean                                          656.013089
# std                                           718.525018
# min                                             0.000000
# 25%                                           194.250000
# 50%                                           448.000000
# 75%                                           843.500000
# max                                          4993.000000
#
#        Number of premises with 10<30Mbit/s download speed  \
# count                                         382.000000
# mean                                         3174.416230
# std                                          2971.853204
# min                                            53.000000
# 25%                                          1454.750000
# 50%                                          2401.500000
# 75%                                          3892.500000
# max                                         25974.000000
#
#        % of premises with 30<300Mbit/s download speed  \
# count                                      382.000000
# mean                                        46.587435
# std                                         25.255563
# min                                          1.100000
# 25%                                         24.225000
# 50%                                         42.450000
# 75%                                         69.850000
# max                                         97.800000
#
#        % of premises with >=300Mbit/s download speed  \
# count                                     382.000000
# mean                                       46.857068
# std                                        28.551654
# min                                         0.000000
# 25%                                        18.450000
# 50%                                        51.800000
# 75%                                        72.175000
# max                                        97.000000
#
#        % of premises with 0<2Mbit/s download speed  \
# count                                   382.000000
# mean                                      0.408639
# std                                       0.794339
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.100000
# 75%                                       0.400000
# max                                       7.900000
#
#        % of premises with 2<5Mbit/s download speed  \
# count                                   382.000000
# mean                                      0.680366
# std                                       0.922826
# min                                       0.000000
# 25%                                       0.100000
# 50%                                       0.300000
# 75%                                       0.800000
# max                                       5.700000
#
#        % of premises with 5<10Mbit/s download speed  \
# count                                    382.000000
# mean                                       0.984817
# std                                        1.247035
# min                                        0.000000
# 25%                                        0.300000
# 50%                                        0.600000
# 75%                                        1.200000
# max                                       11.400000
#
#        % of premises with 10<30Mbit/s download speed
# count                                     382.000000
# mean                                        4.257330
# std                                         3.413865
# min                                         0.100000
# 25%                                         2.100000
# 50%                                         3.550000
# 75%                                         5.700000
# max                                        46.000000
#
# [8 rows x 36 columns]

# %% [markdown]
# ### 2020

# %%
# Check encoding
chardet.detect(open('2023J_TMA02_data/Ofcom_fixed/202009_fixed_laua_coverage_r01.csv','rb').read())
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %% [markdown]
# data file:
# - encoding:  ascii

# %%
# Read the CSV file into a DataFrame
df2020 = pd.read_csv('2023J_TMA02_data/Ofcom_fixed/202009_fixed_laua_coverage_r01.csv', encoding='ascii')
df2020.head()
# Out:
#         laua      laua_name  All Premises  All Matched Premises  \
# 0  S12000033  ABERDEEN CITY        126176                125948
# 1  S12000034  ABERDEENSHIRE        126065                125176
# 2  E07000223           ADUR         29779                 29755
# 3  E07000026      ALLERDALE         51647                 51483
# 4  E07000032   AMBER VALLEY         61134                 60972
#
#    SFBB availability (% premises)  UFBB (100Mbit/s) availability (% premises)  \
# 0                            94.6                                        49.0
# 1                            82.9                                         7.2
# 2                            98.8                                        85.8
# 3                            92.3                                         2.8
# 4                            94.7                                        30.2
#
#    UFBB availability (% premises)  Full Fibre availability (% premises)  \
# 0                            41.6                                  34.9
# 1                             7.0                                   6.9
# 2                            85.6                                   0.6
# 3                             2.8                                   2.8
# 4                            26.7                                  23.6
#
#    Gigabit availability (% premises)  % of premises unable to receive 2Mbit/s  \
# 0                               34.9                                      0.0
# 1                                6.9                                      2.6
# 2                                0.6                                      0.0
# 3                                2.8                                      1.2
# 4                               23.6                                      0.1
#
#    ...  Number of premises with 0<2Mbit/s download speed  \
# 0  ...                                                55
# 1  ...                                              3234
# 2  ...                                                 0
# 3  ...                                               627
# 4  ...                                                63
#
#    Number of premises with 2<5Mbit/s download speed  \
# 0                                               153
# 1                                              3865
# 2                                                10
# 3                                               546
# 4                                               217
#
#    Number of premises with 5<10Mbit/s download speed  \
# 0                                                673
# 1                                               4417
# 2                                                 24
# 3                                                532
# 4                                                293
#
#    Number of premises with 10<30Mbit/s download speed  \
# 0                                               5709
# 1                                               9188
# 2                                                294
# 3                                               2085
# 4                                               2524
#
#    % of premises with 30<300Mbit/s download speed  \
# 0                                            53.0
# 1                                            75.8
# 2                                            13.2
# 3                                            89.5
# 4                                            68.0
#
#    % of premises with >=300Mbit/s download speed  \
# 0                                           41.6
# 1                                            7.0
# 2                                           85.6
# 3                                            2.8
# 4                                           26.7
#
#    % of premises with 0<2Mbit/s download speed  \
# 0                                          0.0
# 1                                          2.6
# 2                                          0.0
# 3                                          1.2
# 4                                          0.1
#
#    % of premises with 2<5Mbit/s download speed  \
# 0                                          0.1
# 1                                          3.1
# 2                                          0.0
# 3                                          1.1
# 4                                          0.4
#
#    % of premises with 5<10Mbit/s download speed  \
# 0                                           0.5
# 1                                           3.5
# 2                                           0.1
# 3                                           1.0
# 4                                           0.5
#
#    % of premises with 10<30Mbit/s download speed
# 0                                            4.5
# 1                                            7.3
# 2                                            1.0
# 3                                            4.0
# 4                                            4.1
#
# [5 rows x 40 columns]

# %%
df2020.tail()
# Out:
#           laua    laua_name  All Premises  All Matched Premises  \
# 374  W06000006      WREXHAM         65867                 65212
# 375  E07000238     WYCHAVON         62536                 62215
# 376  E07000128         WYRE         56527                 56411
# 377  E07000239  WYRE FOREST         48237                 48173
# 378  E06000014         YORK         95949                 95674
#
#      SFBB availability (% premises)  \
# 374                            94.4
# 375                            93.8
# 376                            95.1
# 377                            96.8
# 378                            94.1
#
#      UFBB (100Mbit/s) availability (% premises)  \
# 374                                        37.3
# 375                                        19.2
# 376                                        22.7
# 377                                        47.9
# 378                                        75.5
#
#      UFBB availability (% premises)  Full Fibre availability (% premises)  \
# 374                            36.6                                  36.2
# 375                            15.2                                   8.0
# 376                            22.7                                  22.3
# 377                            47.8                                   2.0
# 378                            71.9                                  54.8
#
#      Gigabit availability (% premises)  \
# 374                               36.2
# 375                                8.1
# 376                               22.3
# 377                               47.8
# 378                               54.8
#
#      % of premises unable to receive 2Mbit/s  ...  \
# 374                                      0.3  ...
# 375                                      0.1  ...
# 376                                      0.1  ...
# 377                                      0.2  ...
# 378                                      0.0  ...
#
#      Number of premises with 0<2Mbit/s download speed  \
# 374                                               194
# 375                                                83
# 376                                                61
# 377                                                84
# 378                                                39
#
#      Number of premises with 2<5Mbit/s download speed  \
# 374                                               445
# 375                                               340
# 376                                               113
# 377                                               134
# 378                                               170
#
#      Number of premises with 5<10Mbit/s download speed  \
# 374                                                578
# 375                                                399
# 376                                                194
# 377                                                171
# 378                                                565
#
#      Number of premises with 10<30Mbit/s download speed  \
# 374                                               1825
# 375                                               2750
# 376                                               2304
# 377                                               1104
# 378                                               4587
#
#      % of premises with 30<300Mbit/s download speed  \
# 374                                            57.7
# 375                                            78.5
# 376                                            72.3
# 377                                            49.0
# 378                                            22.3
#
#      % of premises with >=300Mbit/s download speed  \
# 374                                           36.6
# 375                                           15.2
# 376                                           22.7
# 377                                           47.8
# 378                                           71.9
#
#      % of premises with 0<2Mbit/s download speed  \
# 374                                          0.3
# 375                                          0.1
# 376                                          0.1
# 377                                          0.2
# 378                                          0.0
#
#      % of premises with 2<5Mbit/s download speed  \
# 374                                          0.7
# 375                                          0.5
# 376                                          0.2
# 377                                          0.3
# 378                                          0.2
#
#      % of premises with 5<10Mbit/s download speed  \
# 374                                           0.9
# 375                                           0.6
# 376                                           0.3
# 377                                           0.4
# 378                                           0.6
#
#      % of premises with 10<30Mbit/s download speed
# 374                                            2.8
# 375                                            4.4
# 376                                            4.1
# 377                                            2.3
# 378                                            4.8
#
# [5 rows x 40 columns]

# %%
# Data volume
df2020.shape
# Out:
# (379, 40)

# %%
# Data types
df2020.dtypes
# Out:
# laua                                                             object
# laua_name                                                        object
# All Premises                                                      int64
# All Matched Premises                                              int64
# SFBB availability (% premises)                                  float64
# UFBB (100Mbit/s) availability (% premises)                      float64
# UFBB availability (% premises)                                  float64
# Full Fibre availability (% premises)                            float64
# Gigabit availability (% premises)                               float64
# % of premises unable to receive 2Mbit/s                         float64
# % of premises unable to receive 5Mbit/s                         float64
# % of premises unable to receive 10Mbit/s                        float64
# % of premises unable to receive 30Mbit/s                        float64
# % of premises below the USO                                     float64
# % of premises with NGA                                          float64
# % of premises able to receive decent broadband from FWA         float64
# Number of premises with SFBB availability                         int64
# Number of premises with UFBB (100Mbit/s) availability             int64
# Number of premises with UFBB availability                         int64
# Number of premises with Full Fibre availability                   int64
# Number of premises with Gigabit availability                      int64
# Number of premises unable to receive 2Mbit/s                      int64
# Number of premises unable to receive 5Mbit/s                      int64
# Number of premises unable to receive 10Mbit/s                     int64
# Number of premises unable to receive 30Mbit/s                     int64
# Number of premises below the USO                                  int64
# Number of premises with NGA                                       int64
# Number of premises able to receive decent broadband from FWA      int64
# Number of premises with 30<300Mbit/s download speed               int64
# Number of premises with >=300Mbit/s download speed                int64
# Number of premises with 0<2Mbit/s download speed                  int64
# Number of premises with 2<5Mbit/s download speed                  int64
# Number of premises with 5<10Mbit/s download speed                 int64
# Number of premises with 10<30Mbit/s download speed                int64
# % of premises with 30<300Mbit/s download speed                  float64
# % of premises with >=300Mbit/s download speed                   float64
# % of premises with 0<2Mbit/s download speed                     float64
# % of premises with 2<5Mbit/s download speed                     float64
# % of premises with 5<10Mbit/s download speed                    float64
# % of premises with 10<30Mbit/s download speed                   float64
# dtype: object

# %%
# Count null values
df2020.isnull().sum()
# Out:
# laua                                                            0
# laua_name                                                       0
# All Premises                                                    0
# All Matched Premises                                            0
# SFBB availability (% premises)                                  0
# UFBB (100Mbit/s) availability (% premises)                      0
# UFBB availability (% premises)                                  0
# Full Fibre availability (% premises)                            0
# Gigabit availability (% premises)                               0
# % of premises unable to receive 2Mbit/s                         0
# % of premises unable to receive 5Mbit/s                         0
# % of premises unable to receive 10Mbit/s                        0
# % of premises unable to receive 30Mbit/s                        0
# % of premises below the USO                                     0
# % of premises with NGA                                          0
# % of premises able to receive decent broadband from FWA         0
# Number of premises with SFBB availability                       0
# Number of premises with UFBB (100Mbit/s) availability           0
# Number of premises with UFBB availability                       0
# Number of premises with Full Fibre availability                 0
# Number of premises with Gigabit availability                    0
# Number of premises unable to receive 2Mbit/s                    0
# Number of premises unable to receive 5Mbit/s                    0
# Number of premises unable to receive 10Mbit/s                   0
# Number of premises unable to receive 30Mbit/s                   0
# Number of premises below the USO                                0
# Number of premises with NGA                                     0
# Number of premises able to receive decent broadband from FWA    0
# Number of premises with 30<300Mbit/s download speed             0
# Number of premises with >=300Mbit/s download speed              0
# Number of premises with 0<2Mbit/s download speed                0
# Number of premises with 2<5Mbit/s download speed                0
# Number of premises with 5<10Mbit/s download speed               0
# Number of premises with 10<30Mbit/s download speed              0
# % of premises with 30<300Mbit/s download speed                  0
# % of premises with >=300Mbit/s download speed                   0
# % of premises with 0<2Mbit/s download speed                     0
# % of premises with 2<5Mbit/s download speed                     0
# % of premises with 5<10Mbit/s download speed                    0
# % of premises with 10<30Mbit/s download speed                   0
# dtype: int64

# %%
# Select only numerical columns
numerical_columns = df2020.select_dtypes(include=['number'])

# Use describe on numerical columns
numerical_description = numerical_columns.describe()

# Display the numerical description
display(numerical_description)
# Out:
#         All Premises  All Matched Premises  SFBB availability (% premises)  \
# count     379.000000            379.000000                      379.000000
# mean    82073.034301          81814.664908                       94.187071
# std     54691.926020          54579.787696                        5.414738
# min      1677.000000           1666.000000                       56.500000
# 25%     48481.000000          48342.000000                       93.000000
# 50%     65648.000000          65115.000000                       95.900000
# 75%     99125.000000          98969.000000                       97.600000
# max    474257.000000         473084.000000                       99.600000
#
#        UFBB (100Mbit/s) availability (% premises)  \
# count                                  379.000000
# mean                                    54.782850
# std                                     28.169708
# min                                      0.000000
# 25%                                     30.500000
# 50%                                     61.700000
# 75%                                     78.950000
# max                                     97.500000
#
#        UFBB availability (% premises)  Full Fibre availability (% premises)  \
# count                      379.000000                            379.000000
# mean                        52.300000                             14.926121
# std                         28.214368                             14.855957
# min                          0.000000                              0.000000
# 25%                         26.100000                              4.550000
# 50%                         58.100000                             10.200000
# 75%                         77.750000                             20.100000
# max                         97.500000                             97.500000
#
#        Gigabit availability (% premises)  \
# count                         379.000000
# mean                           21.593931
# std                            22.950617
# min                             0.000000
# 25%                             5.350000
# 50%                            12.700000
# 75%                            25.500000
# max                            97.500000
#
#        % of premises unable to receive 2Mbit/s  \
# count                               379.000000
# mean                                  0.388654
# std                                   0.799870
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.100000
# 75%                                   0.400000
# max                                   8.400000
#
#        % of premises unable to receive 5Mbit/s  \
# count                               379.000000
# mean                                  0.984433
# std                                   1.621302
# min                                   0.000000
# 25%                                   0.100000
# 50%                                   0.300000
# 75%                                   1.000000
# max                                  13.800000
#
#        % of premises unable to receive 10Mbit/s  ...  \
# count                                379.000000  ...
# mean                                   1.832190  ...
# std                                    2.711307  ...
# min                                    0.000000  ...
# 25%                                    0.400000  ...
# 50%                                    0.800000  ...
# 75%                                    2.000000  ...
# max                                   20.700000  ...
#
#        Number of premises with 0<2Mbit/s download speed  \
# count                                        379.000000
# mean                                         233.870712
# std                                          454.429163
# min                                            0.000000
# 25%                                           14.000000
# 50%                                           67.000000
# 75%                                          232.500000
# max                                         4196.000000
#
#        Number of premises with 2<5Mbit/s download speed  \
# count                                        379.000000
# mean                                         377.614776
# std                                          517.932346
# min                                            0.000000
# 25%                                           64.000000
# 50%                                          188.000000
# 75%                                          458.000000
# max                                         3865.000000
#
#        Number of premises with 5<10Mbit/s download speed  \
# count                                         379.000000
# mean                                          569.860158
# std                                           664.281431
# min                                             0.000000
# 25%                                           158.500000
# 50%                                           355.000000
# 75%                                           728.500000
# max                                          4417.000000
#
#        Number of premises with 10<30Mbit/s download speed  \
# count                                         379.000000
# mean                                         2740.870712
# std                                          2705.698190
# min                                            21.000000
# 25%                                          1242.500000
# 50%                                          2024.000000
# 75%                                          3246.500000
# max                                         27281.000000
#
#        % of premises with 30<300Mbit/s download speed  \
# count                                      379.000000
# mean                                        41.887335
# std                                         25.349735
# min                                          0.900000
# 25%                                         19.050000
# 50%                                         36.100000
# 75%                                         64.550000
# max                                         97.600000
#
#        % of premises with >=300Mbit/s download speed  \
# count                                     379.000000
# mean                                       52.300000
# std                                        28.214368
# min                                         0.000000
# 25%                                        26.100000
# 50%                                        58.100000
# 75%                                        77.750000
# max                                        97.500000
#
#        % of premises with 0<2Mbit/s download speed  \
# count                                   379.000000
# mean                                      0.388654
# std                                       0.799870
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.100000
# 75%                                       0.400000
# max                                       8.400000
#
#        % of premises with 2<5Mbit/s download speed  \
# count                                   379.000000
# mean                                      0.592612
# std                                       0.873295
# min                                       0.000000
# 25%                                       0.100000
# 50%                                       0.200000
# 75%                                       0.700000
# max                                       5.500000
#
#        % of premises with 5<10Mbit/s download speed  \
# count                                    379.000000
# mean                                       0.845383
# std                                        1.182164
# min                                        0.000000
# 25%                                        0.200000
# 50%                                        0.500000
# 75%                                        1.000000
# max                                       11.100000
#
#        % of premises with 10<30Mbit/s download speed
# count                                     379.000000
# mean                                        3.613720
# std                                         3.106772
# min                                         0.000000
# 25%                                         1.700000
# 50%                                         2.800000
# 75%                                         4.800000
# max                                        43.300000
#
# [8 rows x 38 columns]

# %%
# Find columns in df2019 but not in df2020
columns_only_in_df2019 = set(df2019.columns) - set(df2020.columns)

# Find columns in df2020 but not in df2019
columns_only_in_df2020 = set(df2020.columns) - set(df2019.columns)

# Display the results
print("Columns only in df2019:", columns_only_in_df2019)
print("Columns only in df2020:", columns_only_in_df2020)
# Out:
# Columns only in df2019: {'% of premises able to receive SFBB from FWA', 'Number of premises able to receive SFBB from FWA'}
# Columns only in df2020: {'Gigabit availability (% premises)', 'Number of premises with UFBB (100Mbit/s) availability', 'UFBB (100Mbit/s) availability (% premises)', 'Number of premises with Gigabit availability'}

# %% [markdown]
# ### 2021

# %%
# Check encoding
chardet.detect(open('2023J_TMA02_data/Ofcom_fixed/202109_fixed_laua_coverage_r01.csv','rb').read())
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %% [markdown]
# data file:
# - encoding:  ascii

# %%
# Read the CSV file into a DataFrame
df2021 = pd.read_csv('2023J_TMA02_data/Ofcom_fixed/202109_fixed_laua_coverage_r01.csv', encoding='ascii')
df2021.head()
# Out:
#         laua      laua_name  All Premises  All Matched Premises  \
# 0  S12000033  ABERDEEN CITY        127714                126771
# 1  S12000034  ABERDEENSHIRE        126481                125378
# 2  E07000223           ADUR         29884                 29793
# 3  E07000026      ALLERDALE         51933                 51622
# 4  E07000032   AMBER VALLEY         61555                 61161
#
#    SFBB availability (% premises)  UFBB (100Mbit/s) availability (% premises)  \
# 0                            94.7                                        66.6
# 1                            82.8                                        13.8
# 2                            98.6                                        85.9
# 3                            92.3                                         3.4
# 4                            95.1                                        31.4
#
#    UFBB availability (% premises)  Full Fibre availability (% premises)  \
# 0                            62.1                                  58.4
# 1                            13.7                                  13.7
# 2                            85.6                                   1.8
# 3                             3.4                                   3.4
# 4                            27.9                                  25.2
#
#    Gigabit availability (% premises)  % of premises unable to receive 2Mbit/s  \
# 0                               58.4                                      0.1
# 1                               13.7                                      2.5
# 2                                1.8                                      0.0
# 3                                3.4                                      1.1
# 4                               25.2                                      0.1
#
#    ...  Number of premises with 0<2Mbit/s download speed  \
# 0  ...                                                67
# 1  ...                                              3202
# 2  ...                                                 4
# 3  ...                                               595
# 4  ...                                                61
#
#    Number of premises with 2<5Mbit/s download speed  \
# 0                                               144
# 1                                              3984
# 2                                                 9
# 3                                               503
# 4                                               129
#
#    Number of premises with 5<10Mbit/s download speed  \
# 0                                                417
# 1                                               4445
# 2                                                 23
# 3                                                514
# 4                                                189
#
#    Number of premises with 10<30Mbit/s download speed  \
# 0                                               5205
# 1                                               8986
# 2                                                281
# 3                                               2088
# 4                                               2266
#
#    % of premises with 30<300Mbit/s download speed  \
# 0                                            32.5
# 1                                            69.1
# 2                                            13.0
# 3                                            88.9
# 4                                            67.2
#
#    % of premises with >=300Mbit/s download speed  \
# 0                                           62.1
# 1                                           13.7
# 2                                           85.6
# 3                                            3.4
# 4                                           27.9
#
#    % of premises with 0<2Mbit/s download speed  \
# 0                                          0.1
# 1                                          2.5
# 2                                          0.0
# 3                                          1.1
# 4                                          0.1
#
#    % of premises with 2<5Mbit/s download speed  \
# 0                                          0.1
# 1                                          3.1
# 2                                          0.0
# 3                                          1.0
# 4                                          0.2
#
#    % of premises with 5<10Mbit/s download speed  \
# 0                                           0.3
# 1                                           3.5
# 2                                           0.1
# 3                                           1.0
# 4                                           0.3
#
#    % of premises with 10<30Mbit/s download speed
# 0                                            4.1
# 1                                            7.1
# 2                                            0.9
# 3                                            4.0
# 4                                            3.7
#
# [5 rows x 40 columns]

# %%
df2021.tail()
# Out:
#           laua    laua_name  All Premises  All Matched Premises  \
# 369  W06000006      WREXHAM         66192                 65306
# 370  E07000238     WYCHAVON         63359                 62695
# 371  E07000128         WYRE         57413                 57099
# 372  E07000239  WYRE FOREST         48472                 48204
# 373  E06000014         YORK         96147                 95638
#
#      SFBB availability (% premises)  \
# 369                            94.6
# 370                            94.2
# 371                            95.4
# 372                            96.7
# 373                            94.2
#
#      UFBB (100Mbit/s) availability (% premises)  \
# 369                                        42.0
# 370                                        23.8
# 371                                        46.4
# 372                                        48.5
# 373                                        77.5
#
#      UFBB availability (% premises)  Full Fibre availability (% premises)  \
# 369                            41.4                                  41.0
# 370                            20.0                                  12.8
# 371                            46.4                                  46.3
# 372                            48.1                                   2.6
# 373                            74.5                                  60.4
#
#      Gigabit availability (% premises)  \
# 369                               41.0
# 370                               17.5
# 371                               46.3
# 372                               48.1
# 373                               72.0
#
#      % of premises unable to receive 2Mbit/s  ...  \
# 369                                      0.2  ...
# 370                                      0.2  ...
# 371                                      0.1  ...
# 372                                      0.1  ...
# 373                                      0.0  ...
#
#      Number of premises with 0<2Mbit/s download speed  \
# 369                                               165
# 370                                               105
# 371                                                46
# 372                                                45
# 373                                                41
#
#      Number of premises with 2<5Mbit/s download speed  \
# 369                                               388
# 370                                               362
# 371                                                94
# 372                                                96
# 373                                               141
#
#      Number of premises with 5<10Mbit/s download speed  \
# 369                                                550
# 370                                                293
# 371                                                221
# 372                                                182
# 373                                                486
#
#      Number of premises with 10<30Mbit/s download speed  \
# 369                                               1614
# 370                                               2245
# 371                                               1981
# 372                                               1022
# 373                                               4361
#
#      % of premises with 30<300Mbit/s download speed  \
# 369                                            53.1
# 370                                            74.2
# 371                                            49.0
# 372                                            48.6
# 373                                            19.7
#
#      % of premises with >=300Mbit/s download speed  \
# 369                                           41.4
# 370                                           20.0
# 371                                           46.4
# 372                                           48.1
# 373                                           74.5
#
#      % of premises with 0<2Mbit/s download speed  \
# 369                                          0.2
# 370                                          0.2
# 371                                          0.1
# 372                                          0.1
# 373                                          0.0
#
#      % of premises with 2<5Mbit/s download speed  \
# 369                                          0.6
# 370                                          0.6
# 371                                          0.2
# 372                                          0.2
# 373                                          0.1
#
#      % of premises with 5<10Mbit/s download speed  \
# 369                                           0.8
# 370                                           0.5
# 371                                           0.4
# 372                                           0.4
# 373                                           0.5
#
#      % of premises with 10<30Mbit/s download speed
# 369                                            2.4
# 370                                            3.5
# 371                                            3.5
# 372                                            2.1
# 373                                            4.5
#
# [5 rows x 40 columns]

# %%
# Data volume
df2021.shape
# Out:
# (374, 40)

# %%
# Count null values
df2021.isnull().sum()
# Out:
# laua                                                            0
# laua_name                                                       0
# All Premises                                                    0
# All Matched Premises                                            0
# SFBB availability (% premises)                                  0
# UFBB (100Mbit/s) availability (% premises)                      0
# UFBB availability (% premises)                                  0
# Full Fibre availability (% premises)                            0
# Gigabit availability (% premises)                               0
# % of premises unable to receive 2Mbit/s                         0
# % of premises unable to receive 5Mbit/s                         0
# % of premises unable to receive 10Mbit/s                        0
# % of premises unable to receive 30Mbit/s                        0
# % of premises below the USO                                     0
# % of premises with NGA                                          0
# % of premises able to receive decent broadband from FWA         0
# Number of premises with SFBB availability                       0
# Number of premises with UFBB (100Mbit/s) availability           0
# Number of premises with UFBB availability                       0
# Number of premises with Full Fibre availability                 0
# Number of premises with Gigabit availability                    0
# Number of premises unable to receive 2Mbit/s                    0
# Number of premises unable to receive 5Mbit/s                    0
# Number of premises unable to receive 10Mbit/s                   0
# Number of premises unable to receive 30Mbit/s                   0
# Number of premises below the USO                                0
# Number of premises with NGA                                     0
# Number of premises able to receive decent broadband from FWA    0
# Number of premises with 30<300Mbit/s download speed             0
# Number of premises with >=300Mbit/s download speed              0
# Number of premises with 0<2Mbit/s download speed                0
# Number of premises with 2<5Mbit/s download speed                0
# Number of premises with 5<10Mbit/s download speed               0
# Number of premises with 10<30Mbit/s download speed              0
# % of premises with 30<300Mbit/s download speed                  0
# % of premises with >=300Mbit/s download speed                   0
# % of premises with 0<2Mbit/s download speed                     0
# % of premises with 2<5Mbit/s download speed                     0
# % of premises with 5<10Mbit/s download speed                    0
# % of premises with 10<30Mbit/s download speed                   0
# dtype: int64

# %%
# Select only numerical columns
numerical_columns2 = df2021.select_dtypes(include=['number'])

# Use describe on numerical columns
numerical_description2 = numerical_columns2.describe()

# Display the numerical description
display(numerical_description2)
# Out:
#         All Premises  All Matched Premises  SFBB availability (% premises)  \
# count     374.000000            374.000000                      374.000000
# mean    83731.264706          83184.727273                       94.344652
# std     55452.666179          55099.509244                        5.246693
# min      1683.000000           1661.000000                       56.500000
# 25%     49355.500000          49097.750000                       93.225000
# 50%     66536.000000          66171.500000                       95.900000
# 75%    101537.000000         100732.500000                       97.500000
# max    474961.000000         471159.000000                       99.500000
#
#        UFBB (100Mbit/s) availability (% premises)  \
# count                                  374.000000
# mean                                    59.760963
# std                                     26.495761
# min                                      1.100000
# 25%                                     39.275000
# 50%                                     67.750000
# 75%                                     82.275000
# max                                     97.600000
#
#        UFBB availability (% premises)  Full Fibre availability (% premises)  \
# count                      374.000000                            374.000000
# mean                        57.726203                             23.960963
# std                         26.509567                             18.610830
# min                          1.100000                              0.900000
# 25%                         36.875000                             10.225000
# 50%                         65.600000                             19.500000
# 75%                         80.500000                             33.575000
# max                         97.600000                             97.600000
#
#        Gigabit availability (% premises)  \
# count                         374.000000
# mean                           38.224599
# std                            28.511055
# min                             0.900000
# 25%                            12.900000
# 50%                            29.900000
# 75%                            66.625000
# max                            97.600000
#
#        % of premises unable to receive 2Mbit/s  \
# count                               374.000000
# mean                                  0.365775
# std                                   0.764637
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.100000
# 75%                                   0.300000
# max                                   8.200000
#
#        % of premises unable to receive 5Mbit/s  \
# count                               374.000000
# mean                                  0.913102
# std                                   1.543772
# min                                   0.000000
# 25%                                   0.100000
# 50%                                   0.300000
# 75%                                   0.900000
# max                                  13.500000
#
#        % of premises unable to receive 10Mbit/s  ...  \
# count                                374.000000  ...
# mean                                   1.681551  ...
# std                                    2.568474  ...
# min                                    0.000000  ...
# 25%                                    0.300000  ...
# 50%                                    0.800000  ...
# 75%                                    1.775000  ...
# max                                   20.100000  ...
#
#        Number of premises with 0<2Mbit/s download speed  \
# count                                        374.000000
# mean                                         223.211230
# std                                          440.084224
# min                                            0.000000
# 25%                                           15.000000
# 50%                                           63.500000
# 75%                                          202.000000
# max                                         4109.000000
#
#        Number of premises with 2<5Mbit/s download speed  \
# count                                        374.000000
# mean                                         358.179144
# std                                          499.915776
# min                                            0.000000
# 25%                                           65.750000
# 50%                                          185.500000
# 75%                                          423.000000
# max                                         3984.000000
#
#        Number of premises with 5<10Mbit/s download speed  \
# count                                          374.00000
# mean                                           523.78877
# std                                            627.13287
# min                                              0.00000
# 25%                                            146.25000
# 50%                                            325.00000
# 75%                                            649.75000
# max                                           4445.00000
#
#        Number of premises with 10<30Mbit/s download speed  \
# count                                         374.000000
# mean                                         2506.422460
# std                                          2550.335573
# min                                            20.000000
# 25%                                          1108.000000
# 50%                                          1832.000000
# 75%                                          3020.250000
# max                                         29149.000000
#
#        % of premises with 30<300Mbit/s download speed  \
# count                                      374.000000
# mean                                        36.614439
# std                                         23.804715
# min                                          0.900000
# 25%                                         16.225000
# 50%                                         29.950000
# 75%                                         54.350000
# max                                         94.800000
#
#        % of premises with >=300Mbit/s download speed  \
# count                                     374.000000
# mean                                       57.726203
# std                                        26.509567
# min                                         1.100000
# 25%                                        36.875000
# 50%                                        65.600000
# 75%                                        80.500000
# max                                        97.600000
#
#        % of premises with 0<2Mbit/s download speed  \
# count                                   374.000000
# mean                                      0.365775
# std                                       0.764637
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.100000
# 75%                                       0.300000
# max                                       8.200000
#
#        % of premises with 2<5Mbit/s download speed  \
# count                                   374.000000
# mean                                      0.545989
# std                                       0.824213
# min                                       0.000000
# 25%                                       0.100000
# 50%                                       0.200000
# 75%                                       0.600000
# max                                       5.300000
#
#        % of premises with 5<10Mbit/s download speed  \
# count                                    374.000000
# mean                                       0.763904
# std                                        1.113291
# min                                        0.000000
# 25%                                        0.200000
# 50%                                        0.400000
# 75%                                        0.800000
# max                                       11.000000
#
#        % of premises with 10<30Mbit/s download speed
# count                                     374.000000
# mean                                        3.281283
# std                                         2.975075
# min                                         0.000000
# 25%                                         1.500000
# 50%                                         2.500000
# 75%                                         4.575000
# max                                        42.000000
#
# [8 rows x 38 columns]

# %%
# Find columns in df2019 but not in df2020
columns_only_in_df2019 = set(df2019.columns) - set(df2021.columns)

# Find columns in df2021 but not in df2019
columns_only_in_df2021 = set(df2021.columns) - set(df2019.columns)

# Display the results
print("Columns only in df2019:", columns_only_in_df2019)
print("Columns only in df2021:", columns_only_in_df2021)
# Out:
# Columns only in df2019: {'% of premises able to receive SFBB from FWA', 'Number of premises able to receive SFBB from FWA'}
# Columns only in df2021: {'Gigabit availability (% premises)', 'Number of premises with UFBB (100Mbit/s) availability', 'UFBB (100Mbit/s) availability (% premises)', 'Number of premises with Gigabit availability'}

# %%
# Find columns in df2020 but not in df2021
columns_only_in_df2020 = set(df2020.columns) - set(df2021.columns)

# Find columns in df2021 but not in df2020
columns_only_in_df2021 = set(df2021.columns) - set(df2020.columns)

# Display the results
print("Columns only in df2019:", columns_only_in_df2020)
print("Columns only in df2021:", columns_only_in_df2021)
# Out:
# Columns only in df2019: set()
# Columns only in df2021: set()

# %% [markdown]
# it has the same columns in 2021 and 2020

# %% [markdown]
# ### 2022

# %%
# Check encoding
chardet.detect(open('2023J_TMA02_data/Ofcom_fixed/202209_fixed_laua_coverage_r02.csv','rb').read())
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
# Read the CSV file into a DataFrame
df2022 = pd.read_csv('2023J_TMA02_data/Ofcom_fixed/202209_fixed_laua_coverage_r02.csv', encoding='ascii')

# %%
df2022.head()
# Out:
#         laua      laua_name  All Premises  All Matched Premises  \
# 0  S12000033  ABERDEEN CITY        128708                128294
# 1  S12000034  ABERDEENSHIRE        127941                127265
# 2  E07000223           ADUR         29971                 29920
# 3  E07000026      ALLERDALE         52309                 52133
# 4  E07000032   AMBER VALLEY         62170                 61902
#
#    SFBB availability (% premises)  UFBB (100Mbit/s) availability (% premises)  \
# 0                            95.8                                        79.1
# 1                            84.2                                        20.6
# 2                            99.1                                        91.0
# 3                            92.7                                         5.4
# 4                            96.1                                        49.4
#
#    UFBB availability (% premises)  Full Fibre availability (% premises)  \
# 0                            77.1                                  74.4
# 1                            20.5                                  20.5
# 2                            91.0                                  54.5
# 3                             5.4                                   5.4
# 4                            46.2                                  43.6
#
#    Gigabit availability (% premises)  % of premises unable to receive 2Mbit/s  \
# 0                               74.4                                      0.0
# 1                               20.5                                      1.8
# 2                               90.1                                      0.0
# 3                                5.4                                      1.2
# 4                               43.7                                      0.1
#
#    ...  Number of premises with 0<2Mbit/s download speed  \
# 0  ...                                                59
# 1  ...                                              2330
# 2  ...                                                 2
# 3  ...                                               630
# 4  ...                                                58
#
#    Number of premises with 2<5Mbit/s download speed  \
# 0                                               119
# 1                                              3450
# 2                                                 6
# 3                                               456
# 4                                               103
#
#    Number of premises with 5<10Mbit/s download speed  \
# 0                                                370
# 1                                               4660
# 2                                                 39
# 3                                                455
# 4                                                126
#
#    Number of premises with 10<30Mbit/s download speed  \
# 0                                               4411
# 1                                               9083
# 2                                                186
# 3                                               2093
# 4                                               1855
#
#    % of premises with 30<300Mbit/s download speed  \
# 0                                            18.8
# 1                                            63.7
# 2                                             8.1
# 3                                            87.3
# 4                                            49.9
#
#    % of premises with >=300Mbit/s download speed  \
# 0                                           77.1
# 1                                           20.5
# 2                                           91.0
# 3                                            5.4
# 4                                           46.2
#
#    % of premises with 0<2Mbit/s download speed  \
# 0                                          0.0
# 1                                          1.8
# 2                                          0.0
# 3                                          1.2
# 4                                          0.1
#
#    % of premises with 2<5Mbit/s download speed  \
# 0                                          0.1
# 1                                          2.7
# 2                                          0.0
# 3                                          0.9
# 4                                          0.2
#
#    % of premises with 5<10Mbit/s download speed  \
# 0                                           0.3
# 1                                           3.6
# 2                                           0.1
# 3                                           0.9
# 4                                           0.2
#
#    % of premises with 10<30Mbit/s download speed
# 0                                            3.4
# 1                                            7.1
# 2                                            0.6
# 3                                            4.0
# 4                                            3.0
#
# [5 rows x 40 columns]

# %%
df2022.tail()
# Out:
#           laua    laua_name  All Premises  All Matched Premises  \
# 369  W06000006      WREXHAM         66672                 65735
# 370  E07000238     WYCHAVON         64057                 63530
# 371  E07000128         WYRE         58069                 57900
# 372  E07000239  WYRE FOREST         48894                 48679
# 373  E06000014         YORK         96526                 96317
#
#      SFBB availability (% premises)  \
# 369                            95.2
# 370                            95.1
# 371                            97.0
# 372                            97.3
# 373                            94.7
#
#      UFBB (100Mbit/s) availability (% premises)  \
# 369                                        48.6
# 370                                        35.8
# 371                                        60.3
# 372                                        55.7
# 373                                        75.8
#
#      UFBB availability (% premises)  Full Fibre availability (% premises)  \
# 369                            48.1                                  47.6
# 370                            31.0                                  29.4
# 371                            60.3                                  60.2
# 372                            55.7                                  10.3
# 373                            72.6                                  52.3
#
#      Gigabit availability (% premises)  \
# 369                               47.6
# 370                               30.7
# 371                               60.3
# 372                               55.4
# 373                               70.0
#
#      % of premises unable to receive 2Mbit/s  ...  \
# 369                                      0.2  ...
# 370                                      0.1  ...
# 371                                      0.1  ...
# 372                                      0.1  ...
# 373                                      0.0  ...
#
#      Number of premises with 0<2Mbit/s download speed  \
# 369                                               132
# 370                                                67
# 371                                                42
# 372                                                49
# 373                                                42
#
#      Number of premises with 2<5Mbit/s download speed  \
# 369                                               349
# 370                                               272
# 371                                                99
# 372                                                87
# 373                                               147
#
#      Number of premises with 5<10Mbit/s download speed  \
# 369                                                447
# 370                                                220
# 371                                                122
# 372                                                114
# 373                                                505
#
#      Number of premises with 10<30Mbit/s download speed  \
# 369                                               1334
# 370                                               2029
# 371                                               1320
# 372                                                872
# 373                                               4175
#
#      % of premises with 30<300Mbit/s download speed  \
# 369                                            47.1
# 370                                            64.1
# 371                                            36.7
# 372                                            41.5
# 373                                            22.2
#
#      % of premises with >=300Mbit/s download speed  \
# 369                                           48.1
# 370                                           31.0
# 371                                           60.3
# 372                                           55.7
# 373                                           72.6
#
#      % of premises with 0<2Mbit/s download speed  \
# 369                                          0.2
# 370                                          0.1
# 371                                          0.1
# 372                                          0.1
# 373                                          0.0
#
#      % of premises with 2<5Mbit/s download speed  \
# 369                                          0.5
# 370                                          0.4
# 371                                          0.2
# 372                                          0.2
# 373                                          0.2
#
#      % of premises with 5<10Mbit/s download speed  \
# 369                                           0.7
# 370                                           0.3
# 371                                           0.2
# 372                                           0.2
# 373                                           0.5
#
#      % of premises with 10<30Mbit/s download speed
# 369                                            2.0
# 370                                            3.2
# 371                                            2.3
# 372                                            1.8
# 373                                            4.3
#
# [5 rows x 40 columns]

# %%
# Data volume
df2022.shape
# Out:
# (374, 40)

# %%
# Count null values
df2022.isnull().sum()
# Out:
# laua                                                            0
# laua_name                                                       0
# All Premises                                                    0
# All Matched Premises                                            0
# SFBB availability (% premises)                                  0
# UFBB (100Mbit/s) availability (% premises)                      0
# UFBB availability (% premises)                                  0
# Full Fibre availability (% premises)                            0
# Gigabit availability (% premises)                               0
# % of premises unable to receive 2Mbit/s                         0
# % of premises unable to receive 5Mbit/s                         0
# % of premises unable to receive 10Mbit/s                        0
# % of premises unable to receive 30Mbit/s                        0
# % of premises below the USO                                     0
# % of premises with NGA                                          0
# % of premises able to receive decent broadband from FWA         0
# Number of premises with SFBB availability                       0
# Number of premises with UFBB (100Mbit/s) availability           0
# Number of premises with UFBB availability                       0
# Number of premises with Full Fibre availability                 0
# Number of premises with Gigabit availability                    0
# Number of premises unable to receive 2Mbit/s                    0
# Number of premises unable to receive 5Mbit/s                    0
# Number of premises unable to receive 10Mbit/s                   0
# Number of premises unable to receive 30Mbit/s                   0
# Number of premises below the USO                                0
# Number of premises with NGA                                     0
# Number of premises able to receive decent broadband from FWA    0
# Number of premises with 30<300Mbit/s download speed             0
# Number of premises with >=300Mbit/s download speed              0
# Number of premises with 0<2Mbit/s download speed                0
# Number of premises with 2<5Mbit/s download speed                0
# Number of premises with 5<10Mbit/s download speed               0
# Number of premises with 10<30Mbit/s download speed              0
# % of premises with 30<300Mbit/s download speed                  0
# % of premises with >=300Mbit/s download speed                   0
# % of premises with 0<2Mbit/s download speed                     0
# % of premises with 2<5Mbit/s download speed                     0
# % of premises with 5<10Mbit/s download speed                    0
# % of premises with 10<30Mbit/s download speed                   0
# dtype: int64

# %%
# Select only numerical columns
numerical_columns3 = df2022.select_dtypes(include=['number'])

# Use describe on numerical columns
numerical_description3 = numerical_columns3.describe()

# Display the numerical description
display(numerical_description3)
# Out:
#         All Premises  All Matched Premises  SFBB availability (% premises)  \
# count     374.000000            374.000000                      374.000000
# mean    84761.181818          84349.454545                       95.325668
# std     56035.842818          55767.364674                        4.584913
# min      1686.000000           1669.000000                       58.700000
# 25%     50147.500000          49881.250000                       94.500000
# 50%     67870.000000          67463.500000                       96.750000
# 75%    102291.250000         102037.000000                       98.000000
# max    477617.000000         475094.000000                       99.500000
#
#        UFBB (100Mbit/s) availability (% premises)  \
# count                                  374.000000
# mean                                    67.605615
# std                                     22.297820
# min                                      1.600000
# 25%                                     52.950000
# 50%                                     74.400000
# 75%                                     85.975000
# max                                     97.700000
#
#        UFBB availability (% premises)  Full Fibre availability (% premises)  \
# count                      374.000000                            374.000000
# mean                        66.110428                             38.207754
# std                         22.464340                             20.553333
# min                          1.600000                              1.600000
# 25%                         50.775000                             22.300000
# 50%                         72.200000                             37.800000
# 75%                         84.800000                             51.275000
# max                         97.700000                             97.700000
#
#        Gigabit availability (% premises)  \
# count                         374.000000
# mean                           64.590642
# std                            22.199580
# min                             1.600000
# 25%                            49.900000
# 50%                            70.350000
# 75%                            83.025000
# max                            97.700000
#
#        % of premises unable to receive 2Mbit/s  \
# count                               374.000000
# mean                                  0.291979
# std                                   0.560008
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.100000
# 75%                                   0.300000
# max                                   3.900000
#
#        % of premises unable to receive 5Mbit/s  \
# count                               374.000000
# mean                                  0.736631
# std                                   1.171155
# min                                   0.000000
# 25%                                   0.100000
# 50%                                   0.300000
# 75%                                   0.800000
# max                                   7.100000
#
#        % of premises unable to receive 10Mbit/s  ...  \
# count                                374.000000  ...
# mean                                   1.362299  ...
# std                                    2.090665  ...
# min                                    0.000000  ...
# 25%                                    0.300000  ...
# 50%                                    0.650000  ...
# 75%                                    1.400000  ...
# max                                   17.300000  ...
#
#        Number of premises with 0<2Mbit/s download speed  \
# count                                        374.000000
# mean                                         184.927807
# std                                          338.461553
# min                                            0.000000
# 25%                                           14.250000
# 50%                                           55.000000
# 75%                                          186.750000
# max                                         2526.000000
#
#        Number of premises with 2<5Mbit/s download speed  \
# count                                        374.000000
# mean                                         293.545455
# std                                          402.030606
# min                                            0.000000
# 25%                                           52.250000
# 50%                                          153.000000
# 75%                                          363.000000
# max                                         3450.000000
#
#        Number of premises with 5<10Mbit/s download speed  \
# count                                         374.000000
# mean                                          433.122995
# std                                           548.774815
# min                                             0.000000
# 25%                                           115.250000
# 50%                                           265.000000
# 75%                                           504.250000
# max                                          4660.000000
#
#        Number of premises with 10<30Mbit/s download speed  \
# count                                         374.000000
# mean                                         2170.133690
# std                                          2335.513567
# min                                            10.000000
# 25%                                           935.500000
# 50%                                          1522.500000
# 75%                                          2482.000000
# max                                         26434.000000
#
#        % of premises with 30<300Mbit/s download speed  \
# count                                      374.000000
# mean                                        29.213904
# std                                         20.007487
# min                                          0.800000
# 25%                                         12.400000
# 50%                                         23.800000
# 75%                                         43.200000
# max                                         95.100000
#
#        % of premises with >=300Mbit/s download speed  \
# count                                     374.000000
# mean                                       66.110428
# std                                        22.464340
# min                                         1.600000
# 25%                                        50.775000
# 50%                                        72.200000
# 75%                                        84.800000
# max                                        97.700000
#
#        % of premises with 0<2Mbit/s download speed  \
# count                                   374.000000
# mean                                      0.291979
# std                                       0.560008
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.100000
# 75%                                       0.300000
# max                                       3.900000
#
#        % of premises with 2<5Mbit/s download speed  \
# count                                   374.000000
# mean                                      0.437166
# std                                       0.647729
# min                                       0.000000
# 25%                                       0.100000
# 50%                                       0.200000
# 75%                                       0.500000
# max                                       4.300000
#
#        % of premises with 5<10Mbit/s download speed  \
# count                                    374.000000
# mean                                       0.624332
# std                                        1.005039
# min                                        0.000000
# 25%                                        0.200000
# 50%                                        0.350000
# 75%                                        0.700000
# max                                       10.900000
#
#        % of premises with 10<30Mbit/s download speed
# count                                     374.000000
# mean                                        2.804813
# std                                         2.783777
# min                                         0.000000
# 25%                                         1.300000
# 50%                                         2.100000
# 75%                                         3.600000
# max                                        39.300000
#
# [8 rows x 38 columns]

# %%
# Find columns in df2019 but not in df2020
columns_only_in_df2019 = set(df2019.columns) - set(df2022.columns)

# Find columns in df2020 but not in df2019
columns_only_in_df2022 = set(df2022.columns) - set(df2019.columns)

# Display the results
print("Columns only in df2019:", columns_only_in_df2019)
print("Columns only in df2020:", columns_only_in_df2022)
# Out:
# Columns only in df2019: {'% of premises able to receive SFBB from FWA', 'Number of premises able to receive SFBB from FWA'}
# Columns only in df2020: {'Gigabit availability (% premises)', 'Number of premises with UFBB (100Mbit/s) availability', 'UFBB (100Mbit/s) availability (% premises)', 'Number of premises with Gigabit availability'}

# %%
# Find columns in df2021 but not in df2020
columns_only_in_df2021 = set(df2021.columns) - set(df2022.columns)

# Find columns in df2020 but not in df2021
columns_only_in_df2022 = set(df2022.columns) - set(df2021.columns)

# Display the results
print("Columns only in df2021:", columns_only_in_df2021)
print("Columns only in df2020:", columns_only_in_df2022)
# Out:
# Columns only in df2021: set()
# Columns only in df2020: set()

# %% [markdown]
# Columns: 2020, 2021, 2022 are the same

# %% [markdown]
# ### 2023

# %%
# Check encoding
chardet.detect(open('2023J_TMA02_data/Ofcom_fixed/202305_fixed_laua_coverage_r02.csv','rb').read())
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
# Read the CSV file into a DataFrame
df2023 = pd.read_csv('2023J_TMA02_data/Ofcom_fixed/202305_fixed_laua_coverage_r02.csv', encoding='ascii')
df2023.head()
# Out:
#         laua      laua_name  All Premises  All Matched Premises  \
# 0  S12000033  ABERDEEN CITY        129315                129197
# 1  S12000034  ABERDEENSHIRE        128408                128070
# 2  E07000223           ADUR         29985                 29953
# 3  E07000026      ALLERDALE         52482                 52364
# 4  E07000032   AMBER VALLEY         62512                 62430
#
#    SFBB availability (% premises)  UFBB (100Mbit/s) availability (% premises)  \
# 0                            97.2                                        84.8
# 1                            85.9                                        25.5
# 2                            99.1                                        92.8
# 3                            93.1                                         6.0
# 4                            97.2                                        62.4
#
#    UFBB availability (% premises)  Full Fibre availability (% premises)  \
# 0                            83.9                                  83.0
# 1                            25.5                                  25.4
# 2                            92.8                                  65.4
# 3                             6.0                                   6.0
# 4                            60.6                                  59.0
#
#    Gigabit availability (% premises)  % of premises unable to receive 2Mbit/s  \
# 0                               83.0                                      0.0
# 1                               25.4                                      1.7
# 2                               92.8                                      0.0
# 3                                6.0                                      1.2
# 4                               59.1                                      0.1
#
#    ...  Number of premises with 0<2Mbit/s download speed  \
# 0  ...                                                58
# 1  ...                                              2214
# 2  ...                                                 0
# 3  ...                                               617
# 4  ...                                                42
#
#    Number of premises with 2<5Mbit/s download speed  \
# 0                                               151
# 1                                              3193
# 2                                                 9
# 3                                               440
# 4                                               115
#
#    Number of premises with 5<10Mbit/s download speed  \
# 0                                                222
# 1                                               4296
# 2                                                 31
# 3                                                422
# 4                                                 88
#
#    Number of premises with 10<30Mbit/s download speed  \
# 0                                               3130
# 1                                               8071
# 2                                                186
# 3                                               2000
# 4                                               1415
#
#    % of premises with 30<300Mbit/s download speed  \
# 0                                            13.2
# 1                                            60.4
# 2                                             6.3
# 3                                            87.2
# 4                                            36.6
#
#    % of premises with >=300Mbit/s download speed  \
# 0                                           83.9
# 1                                           25.5
# 2                                           92.8
# 3                                            6.0
# 4                                           60.6
#
#    % of premises with 0<2Mbit/s download speed  \
# 0                                          0.0
# 1                                          1.7
# 2                                          0.0
# 3                                          1.2
# 4                                          0.1
#
#    % of premises with 2<5Mbit/s download speed  \
# 0                                          0.1
# 1                                          2.5
# 2                                          0.0
# 3                                          0.8
# 4                                          0.2
#
#    % of premises with 5<10Mbit/s download speed  \
# 0                                           0.2
# 1                                           3.3
# 2                                           0.1
# 3                                           0.8
# 4                                           0.1
#
#    % of premises with 10<30Mbit/s download speed
# 0                                            2.4
# 1                                            6.3
# 2                                            0.6
# 3                                            3.8
# 4                                            2.3
#
# [5 rows x 40 columns]

# %%
df2023.head()
# Out:
#         laua      laua_name  All Premises  All Matched Premises  \
# 0  S12000033  ABERDEEN CITY        129315                129197
# 1  S12000034  ABERDEENSHIRE        128408                128070
# 2  E07000223           ADUR         29985                 29953
# 3  E07000026      ALLERDALE         52482                 52364
# 4  E07000032   AMBER VALLEY         62512                 62430
#
#    SFBB availability (% premises)  UFBB (100Mbit/s) availability (% premises)  \
# 0                            97.2                                        84.8
# 1                            85.9                                        25.5
# 2                            99.1                                        92.8
# 3                            93.1                                         6.0
# 4                            97.2                                        62.4
#
#    UFBB availability (% premises)  Full Fibre availability (% premises)  \
# 0                            83.9                                  83.0
# 1                            25.5                                  25.4
# 2                            92.8                                  65.4
# 3                             6.0                                   6.0
# 4                            60.6                                  59.0
#
#    Gigabit availability (% premises)  % of premises unable to receive 2Mbit/s  \
# 0                               83.0                                      0.0
# 1                               25.4                                      1.7
# 2                               92.8                                      0.0
# 3                                6.0                                      1.2
# 4                               59.1                                      0.1
#
#    ...  Number of premises with 0<2Mbit/s download speed  \
# 0  ...                                                58
# 1  ...                                              2214
# 2  ...                                                 0
# 3  ...                                               617
# 4  ...                                                42
#
#    Number of premises with 2<5Mbit/s download speed  \
# 0                                               151
# 1                                              3193
# 2                                                 9
# 3                                               440
# 4                                               115
#
#    Number of premises with 5<10Mbit/s download speed  \
# 0                                                222
# 1                                               4296
# 2                                                 31
# 3                                                422
# 4                                                 88
#
#    Number of premises with 10<30Mbit/s download speed  \
# 0                                               3130
# 1                                               8071
# 2                                                186
# 3                                               2000
# 4                                               1415
#
#    % of premises with 30<300Mbit/s download speed  \
# 0                                            13.2
# 1                                            60.4
# 2                                             6.3
# 3                                            87.2
# 4                                            36.6
#
#    % of premises with >=300Mbit/s download speed  \
# 0                                           83.9
# 1                                           25.5
# 2                                           92.8
# 3                                            6.0
# 4                                           60.6
#
#    % of premises with 0<2Mbit/s download speed  \
# 0                                          0.0
# 1                                          1.7
# 2                                          0.0
# 3                                          1.2
# 4                                          0.1
#
#    % of premises with 2<5Mbit/s download speed  \
# 0                                          0.1
# 1                                          2.5
# 2                                          0.0
# 3                                          0.8
# 4                                          0.2
#
#    % of premises with 5<10Mbit/s download speed  \
# 0                                           0.2
# 1                                           3.3
# 2                                           0.1
# 3                                           0.8
# 4                                           0.1
#
#    % of premises with 10<30Mbit/s download speed
# 0                                            2.4
# 1                                            6.3
# 2                                            0.6
# 3                                            3.8
# 4                                            2.3
#
# [5 rows x 40 columns]

# %%
# Data volume
df2023.shape
# Out:
# (374, 40)

# %%
# Count null values
df2023.isnull().sum()
# Out:
# laua                                                            0
# laua_name                                                       0
# All Premises                                                    0
# All Matched Premises                                            0
# SFBB availability (% premises)                                  0
# UFBB (100Mbit/s) availability (% premises)                      0
# UFBB availability (% premises)                                  0
# Full Fibre availability (% premises)                            0
# Gigabit availability (% premises)                               0
# % of premises unable to receive 2Mbit/s                         0
# % of premises unable to receive 5Mbit/s                         0
# % of premises unable to receive 10Mbit/s                        0
# % of premises unable to receive 30Mbit/s                        0
# % of premises below the USO                                     0
# % of premises with NGA                                          0
# % of premises able to receive decent broadband from FWA         0
# Number of premises with SFBB availability                       0
# Number of premises with UFBB (100Mbit/s) availability           0
# Number of premises with UFBB availability                       0
# Number of premises with Full Fibre availability                 0
# Number of premises with Gigabit availability                    0
# Number of premises unable to receive 2Mbit/s                    0
# Number of premises unable to receive 5Mbit/s                    0
# Number of premises unable to receive 10Mbit/s                   0
# Number of premises unable to receive 30Mbit/s                   0
# Number of premises below the USO                                0
# Number of premises with NGA                                     0
# Number of premises able to receive decent broadband from FWA    0
# Number of premises with 30<300Mbit/s download speed             0
# Number of premises with >=300Mbit/s download speed              0
# Number of premises with 0<2Mbit/s download speed                0
# Number of premises with 2<5Mbit/s download speed                0
# Number of premises with 5<10Mbit/s download speed               0
# Number of premises with 10<30Mbit/s download speed              0
# % of premises with 30<300Mbit/s download speed                  0
# % of premises with >=300Mbit/s download speed                   0
# % of premises with 0<2Mbit/s download speed                     0
# % of premises with 2<5Mbit/s download speed                     0
# % of premises with 5<10Mbit/s download speed                    0
# % of premises with 10<30Mbit/s download speed                   0
# dtype: int64

# %%
# Select only numerical columns
numerical_columns4 = df2023.select_dtypes(include=['number'])

# Use describe on numerical columns
numerical_description4 = numerical_columns4.describe()

# Display the numerical description
display(numerical_description4)
# Out:
#         All Premises  All Matched Premises  SFBB availability (% premises)  \
# count     374.000000            374.000000                      374.000000
# mean    85116.336898          84886.005348                       96.072995
# std     56252.163193          56070.215034                        4.211346
# min      1689.000000           1678.000000                       59.100000
# 25%     50502.250000          50250.000000                       95.400000
# 50%     68136.500000          67915.000000                       97.300000
# 75%    102462.000000         102371.250000                       98.300000
# max    478734.000000         476604.000000                       99.800000
#
#        UFBB (100Mbit/s) availability (% premises)  \
# count                                  374.000000
# mean                                    71.809091
# std                                     20.414938
# min                                      1.800000
# 25%                                     59.075000
# 50%                                     77.050000
# 75%                                     88.175000
# max                                     98.400000
#
#        UFBB availability (% premises)  Full Fibre availability (% premises)  \
# count                      374.000000                            374.000000
# mean                        70.550802                             47.627807
# std                         20.496678                             20.763319
# min                          1.800000                              1.800000
# 25%                         57.550000                             32.175000
# 50%                         75.350000                             48.450000
# 75%                         87.200000                             62.050000
# max                         98.400000                             98.400000
#
#        Gigabit availability (% premises)  \
# count                         374.000000
# mean                           69.724866
# std                            20.390288
# min                             1.800000
# 25%                            57.475000
# 50%                            74.400000
# 75%                            86.850000
# max                            98.400000
#
#        % of premises unable to receive 2Mbit/s  \
# count                               374.000000
# mean                                  0.274064
# std                                   0.504081
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.100000
# 75%                                   0.300000
# max                                   3.300000
#
#        % of premises unable to receive 5Mbit/s  \
# count                               374.000000
# mean                                  0.679412
# std                                   1.073881
# min                                   0.000000
# 25%                                   0.100000
# 50%                                   0.300000
# 75%                                   0.700000
# max                                   7.300000
#
#        % of premises unable to receive 10Mbit/s  ...  \
# count                                374.000000  ...
# mean                                   1.239305  ...
# std                                    1.937932  ...
# min                                    0.000000  ...
# 25%                                    0.300000  ...
# 50%                                    0.600000  ...
# 75%                                    1.200000  ...
# max                                   16.700000  ...
#
#        Number of premises with 0<2Mbit/s download speed  \
# count                                        374.000000
# mean                                         175.125668
# std                                          304.743680
# min                                            0.000000
# 25%                                           19.000000
# 50%                                           57.500000
# 75%                                          185.750000
# max                                         2568.000000
#
#        Number of premises with 2<5Mbit/s download speed  \
# count                                        374.000000
# mean                                         272.219251
# std                                          378.581337
# min                                            0.000000
# 25%                                           54.250000
# 50%                                          137.000000
# 75%                                          334.000000
# max                                         3193.000000
#
#        Number of premises with 5<10Mbit/s download speed  \
# count                                         374.000000
# mean                                          392.620321
# std                                           508.478333
# min                                             0.000000
# 25%                                           100.000000
# 50%                                           240.000000
# 75%                                           467.750000
# max                                          4296.000000
#
#        Number of premises with 10<30Mbit/s download speed  \
# count                                         374.000000
# mean                                         1865.080214
# std                                          2071.790679
# min                                            26.000000
# 25%                                           803.000000
# 50%                                          1267.500000
# 75%                                          2143.750000
# max                                         24111.000000
#
#        % of premises with 30<300Mbit/s download speed  \
# count                                      374.000000
# mean                                        25.524064
# std                                         18.175820
# min                                          0.200000
# 25%                                         10.575000
# 50%                                         21.250000
# 75%                                         36.600000
# max                                         95.900000
#
#        % of premises with >=300Mbit/s download speed  \
# count                                     374.000000
# mean                                       70.550802
# std                                        20.496678
# min                                         1.800000
# 25%                                        57.550000
# 50%                                        75.350000
# 75%                                        87.200000
# max                                        98.400000
#
#        % of premises with 0<2Mbit/s download speed  \
# count                                   374.000000
# mean                                      0.274064
# std                                       0.504081
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.100000
# 75%                                       0.300000
# max                                       3.300000
#
#        % of premises with 2<5Mbit/s download speed  \
# count                                   374.000000
# mean                                      0.397594
# std                                       0.604247
# min                                       0.000000
# 25%                                       0.100000
# 50%                                       0.200000
# 75%                                       0.400000
# max                                       4.300000
#
#        % of premises with 5<10Mbit/s download speed  \
# count                                    374.000000
# mean                                       0.560695
# std                                        0.939757
# min                                        0.000000
# 25%                                        0.100000
# 50%                                        0.300000
# 75%                                        0.600000
# max                                       10.600000
#
#        % of premises with 10<30Mbit/s download speed
# count                                     374.000000
# mean                                        2.404011
# std                                         2.639301
# min                                         0.000000
# 25%                                         1.100000
# 50%                                         1.700000
# 75%                                         3.075000
# max                                        39.800000
#
# [8 rows x 38 columns]

# %%
# Find columns in df2019 but not in df2023
columns_only_in_df2019 = set(df2019.columns) - set(df2023.columns)

# Find columns in df2023 but not in df2019
columns_only_in_df2023 = set(df2023.columns) - set(df2019.columns)

# Display the results
print("Columns only in df2019:", columns_only_in_df2019)
print("Columns only in df2023:", columns_only_in_df2023)
# Out:
# Columns only in df2019: {'% of premises able to receive SFBB from FWA', 'Number of premises able to receive SFBB from FWA'}
# Columns only in df2023: {'Gigabit availability (% premises)', 'Number of premises with UFBB (100Mbit/s) availability', 'UFBB (100Mbit/s) availability (% premises)', 'Number of premises with Gigabit availability'}

# %%
# Find columns in df2020 but not in df2023
columns_only_in_df2020 = set(df2020.columns) - set(df2023.columns)

# Find columns in df2023 but not in df2020
columns_only_in_df2023 = set(df2023.columns) - set(df2020.columns)

# Display the results
print("Columns only in df2020:", columns_only_in_df2020)
print("Columns only in df2023:", columns_only_in_df2023)
# Out:
# Columns only in df2020: set()
# Columns only in df2023: set()

# %%
df2019.dtypes
# Out:
# laua                                                             object
# laua_name                                                        object
# All Premises                                                      int64
# All Matched Premises                                              int64
# SFBB availability (% premises)                                  float64
# UFBB availability (% premises)                                  float64
# Full Fibre availability (% premises)                            float64
# % of premises unable to receive 2Mbit/s                         float64
# % of premises unable to receive 5Mbit/s                         float64
# % of premises unable to receive 10Mbit/s                        float64
# % of premises unable to receive 30Mbit/s                        float64
# % of premises below the USO                                     float64
# % of premises with NGA                                          float64
# % of premises able to receive decent broadband from FWA         float64
# % of premises able to receive SFBB from FWA                     float64
# Number of premises with SFBB availability                         int64
# Number of premises with UFBB availability                         int64
# Number of premises with Full Fibre availability                   int64
# Number of premises unable to receive 2Mbit/s                      int64
# Number of premises unable to receive 5Mbit/s                      int64
# Number of premises unable to receive 10Mbit/s                     int64
# Number of premises unable to receive 30Mbit/s                     int64
# Number of premises below the USO                                  int64
# Number of premises with NGA                                       int64
# Number of premises able to receive decent broadband from FWA      int64
# Number of premises able to receive SFBB from FWA                  int64
# Number of premises with 30<300Mbit/s download speed               int64
# Number of premises with >=300Mbit/s download speed                int64
# Number of premises with 0<2Mbit/s download speed                  int64
# Number of premises with 2<5Mbit/s download speed                  int64
# Number of premises with 5<10Mbit/s download speed                 int64
# Number of premises with 10<30Mbit/s download speed                int64
# % of premises with 30<300Mbit/s download speed                  float64
# % of premises with >=300Mbit/s download speed                   float64
# % of premises with 0<2Mbit/s download speed                     float64
# % of premises with 2<5Mbit/s download speed                     float64
# % of premises with 5<10Mbit/s download speed                    float64
# % of premises with 10<30Mbit/s download speed                   float64
# dtype: object

# %% [markdown]
# The dataframe of df2019 has not the column related to Gigabit('Gigabit availability (% premises)' and 'Number of premises with Gigabit availability').

# %% [markdown]
# The columns names of df2019: 'Number of premises able to receive SFBB from FWA' '% of premises able to receive SFBB from FWA' of df2019 are the same as 'SFBB availability (% premises)' and 'Number of premises with SFBB availability' respectively.
# In addition, the columns from 'UFBB availability (% premises)' and 'Number of premises with UFBB (100Mbit/s) availability' from df2019 are the same as 'UFBB (100Mbit/s) availability (% premises)' and 'Number of premises with UFBB (100Mbit/s) availability' from other dataframes (2020 - 2023).
#
# Therefore, the names of df2019 are changed

# %%
df2019.rename(columns={'Number of premises able to receive SFBB from FWA':'Number of premises with SFBB availability',
                       '% of premises able to receive SFBB from FWA': 'SFBB availability (% premises)',
                       'UFBB availability (% premises)': 'UFBB (100Mbit/s) availability (% premises)', 
                       'Number of premises with UFBB (100Mbit/s) availability' : 'Number of premises with UFBB (100Mbit/s) availability'
                      },
              inplace=True)

# %%
# Data types
df2023.dtypes
# Out:
# laua                                                             object
# laua_name                                                        object
# All Premises                                                      int64
# All Matched Premises                                              int64
# SFBB availability (% premises)                                  float64
# UFBB (100Mbit/s) availability (% premises)                      float64
# UFBB availability (% premises)                                  float64
# Full Fibre availability (% premises)                            float64
# Gigabit availability (% premises)                               float64
# % of premises unable to receive 2Mbit/s                         float64
# % of premises unable to receive 5Mbit/s                         float64
# % of premises unable to receive 10Mbit/s                        float64
# % of premises unable to receive 30Mbit/s                        float64
# % of premises below the USO                                     float64
# % of premises with NGA                                          float64
# % of premises able to receive decent broadband from FWA         float64
# Number of premises with SFBB availability                         int64
# Number of premises with UFBB (100Mbit/s) availability             int64
# Number of premises with UFBB availability                         int64
# Number of premises with Full Fibre availability                   int64
# Number of premises with Gigabit availability                      int64
# Number of premises unable to receive 2Mbit/s                      int64
# Number of premises unable to receive 5Mbit/s                      int64
# Number of premises unable to receive 10Mbit/s                     int64
# Number of premises unable to receive 30Mbit/s                     int64
# Number of premises below the USO                                  int64
# Number of premises with NGA                                       int64
# Number of premises able to receive decent broadband from FWA      int64
# Number of premises with 30<300Mbit/s download speed               int64
# Number of premises with >=300Mbit/s download speed                int64
# Number of premises with 0<2Mbit/s download speed                  int64
# Number of premises with 2<5Mbit/s download speed                  int64
# Number of premises with 5<10Mbit/s download speed                 int64
# Number of premises with 10<30Mbit/s download speed                int64
# % of premises with 30<300Mbit/s download speed                  float64
# % of premises with >=300Mbit/s download speed                   float64
# % of premises with 0<2Mbit/s download speed                     float64
# % of premises with 2<5Mbit/s download speed                     float64
# % of premises with 5<10Mbit/s download speed                    float64
# % of premises with 10<30Mbit/s download speed                   float64
# dtype: object

# %%
# Find 'laua_name' values in 2019 but not in 2020
laua_names_only_in_2019 = set(df2019['laua_name']) - set(df2020['laua_name'])

# Display the results
display("laua_name values only in 2019:", laua_names_only_in_2019)

# Find 'laua_name' values in 2020 but not in 2019
laua_names_only_in_2020 = set(df2020['laua_name']) - set(df2019['laua_name'])

# Display the results
display("laua_name values only in 2020:", laua_names_only_in_2020)
# Out:
# 'laua_name values only in 2019:'
# {'AYLESBURY VALE', 'CHILTERN', 'SOUTH BUCKS', 'WYCOMBE'}
# 'laua_name values only in 2020:'
# {'BUCKINGHAMSHIRE'}

# %%
# Find 'laua_name' values in 2019 but not in 2021
laua_names_only_in_2019 = set(df2019['laua_name']) - set(df2021['laua_name'])

# Display the results
display("laua_name values only in 2019:", laua_names_only_in_2019)

# Find 'laua_name' values in 2021 but not in 2019
laua_names_only_in_2021 = set(df2021['laua_name']) - set(df2019['laua_name'])

# Display the results
display("laua_name values only in 2021:", laua_names_only_in_2021)
# Out:
# 'laua_name values only in 2019:'
# {'AYLESBURY VALE',
#  'CHILTERN',
#  'CORBY',
#  'DAVENTRY',
#  'EAST NORTHAMPTONSHIRE',
#  'KETTERING',
#  'NORTHAMPTON',
#  'SOUTH BUCKS',
#  'SOUTH NORTHAMPTONSHIRE',
#  'WELLINGBOROUGH',
#  'WYCOMBE'}
# 'laua_name values only in 2021:'
# {'BUCKINGHAMSHIRE', 'NORTH NORTHAMPTONSHIRE', 'WEST NORTHAMPTONSHIRE'}

# %%
# Find 'laua_name' values in 2019 but not in 2022
laua_names_only_in_2019 = set(df2019['laua_name']) - set(df2022['laua_name'])

# Display the results
display("laua_name values only in 2019:", laua_names_only_in_2019)

# Find 'laua_name' values in 2022 but not in 2019
laua_names_only_in_2022 = set(df2022['laua_name']) - set(df2019['laua_name'])

# Display the results
display("laua_name values only in 2023:", laua_names_only_in_2022)
# Out:
# 'laua_name values only in 2019:'
# {'AYLESBURY VALE',
#  'CHILTERN',
#  'CORBY',
#  'DAVENTRY',
#  'EAST NORTHAMPTONSHIRE',
#  'KETTERING',
#  'NORTHAMPTON',
#  'SOUTH BUCKS',
#  'SOUTH NORTHAMPTONSHIRE',
#  'WELLINGBOROUGH',
#  'WYCOMBE'}
# 'laua_name values only in 2023:'
# {'BUCKINGHAMSHIRE', 'NORTH NORTHAMPTONSHIRE', 'WEST NORTHAMPTONSHIRE'}

# %%
# Find 'laua_name' values in 2019 but not in 2023
laua_names_only_in_2019 = set(df2019['laua_name']) - set(df2023['laua_name'])

# Display the results
display("laua_name values only in 2019:", laua_names_only_in_2019)

# Find 'laua_name' values in 2023 but not in 2019
laua_names_only_in_2023 = set(df2023['laua_name']) - set(df2019['laua_name'])

# Display the results
display("laua_name values only in 2023:", laua_names_only_in_2023)
# Out:
# 'laua_name values only in 2019:'
# {'AYLESBURY VALE',
#  'CHILTERN',
#  'CORBY',
#  'DAVENTRY',
#  'EAST NORTHAMPTONSHIRE',
#  'KETTERING',
#  'NORTHAMPTON',
#  'SOUTH BUCKS',
#  'SOUTH NORTHAMPTONSHIRE',
#  'WELLINGBOROUGH',
#  'WYCOMBE'}
# 'laua_name values only in 2023:'
# {'BUCKINGHAMSHIRE', 'NORTH NORTHAMPTONSHIRE', 'WEST NORTHAMPTONSHIRE'}

# %%
# Find 'laua_name' values in 2020 but not in 2021
laua_names_only_in_2020 = set(df2020['laua_name']) - set(df2021['laua_name'])

# Display the results
display("laua_name values only in 2020:", laua_names_only_in_2020)

# Find 'laua_name' values in 2021 but not in 2020
laua_names_only_in_2021 = set(df2021['laua_name']) - set(df2020['laua_name'])

# Display the results
display("laua_name values only in 2023:", laua_names_only_in_2021)
# Out:
# 'laua_name values only in 2020:'
# {'CORBY',
#  'DAVENTRY',
#  'EAST NORTHAMPTONSHIRE',
#  'KETTERING',
#  'NORTHAMPTON',
#  'SOUTH NORTHAMPTONSHIRE',
#  'WELLINGBOROUGH'}
# 'laua_name values only in 2023:'
# {'NORTH NORTHAMPTONSHIRE', 'WEST NORTHAMPTONSHIRE'}

# %% [markdown]
# Some values in laua_name are missing. However, in storing data in MongoDB, advantage was taken of its flexible structure, allowing documents to have different fields. Therefore, filling in missing values with null was not chosen.

# %% [markdown]
# ### Store the data

# %%
MONGO_CONNECTION_STRING = f"mongodb://localhost:27017/"
print(f"MONGO_CONNECTION_STRING = {MONGO_CONNECTION_STRING}")
# Out:
# MONGO_CONNECTION_STRING = mongodb://localhost:27017/

# %%
from pymongo import MongoClient
mongo_client = MongoClient(MONGO_CONNECTION_STRING)
DB_NAME = "Q1_TMA02_TM351"  
print(f"DB_NAME = {DB_NAME}")

mongo_db = mongo_client[DB_NAME]
# Out:
# DB_NAME = Q1_TMA02_TM351

# %%
import os
from pymongo import MongoClient


# List of DataFrames and corresponding years
dataframes = [df2019, df2020, df2021, df2022, df2023]
years = [2019, 2020, 2021, 2022, 2023]

for df, year in zip(dataframes, years):
    # Drop the 'year' column if it already exists
    if 'year' in df.columns:
        df = df.drop(columns=['year'])

    # Add a field for the year
    df['year'] = year

    # Convert DataFrame to list of dictionaries
    records = df.to_dict(orient='records')

    # Specify the collection name based on the year
    collection_name = f'data_{year}'

    # Insert data into MongoDB
    mongo_db[collection_name].insert_many(records)
# Out:
# /tmp/ipykernel_412/1316622539.py:18: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   records = df.to_dict(orient='records')

# %% [markdown]
# As you prepared the data for entry into mongoDB you would find that the dataset contained dirty and missing data. Give three examples where you identified problems with the data. Explain how you resolved these problems and what the implications might be when you analyse the data.
#
# *(5 marks)*

# %% [markdown]
# **Write your answer in this markdown cell**
#
#
# In the process of preparing data for entry into MongoDB, three instances of data quality issues were identified.
#
# Firstly, within each CSV dataset representing a specific year, the 'year' information was absent. To address this, the integration process ensured the addition of 'year' information.
#
# Secondly, there are missing values. While columns related to 'Gigabit' were present from 2020 to 2023, there was a gap in the information for the year 2019. Regarding the 'laua_name' column, some local authorities are missing in each dataframe. However, in storing data in MongoDB, advantage was taken of its flexible structure, allowing documents to have different fields. Therefore, filling in missing values with null was not chosen. This decision aligns with MongoDB's ability to handle sparse data effectively, providing flexibility for future changes in the data structure without disrupting existing documents.
#
# Thirdly, a discrepancy was observed in the column names for 'SFBB' and 'UFBB' between 2019 and the subsequent years (2020-2023). To establish consistency, the column names in 2019 were changed to match those from 2020 to 2023.
